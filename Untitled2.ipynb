# %%
'''Example script showing how to use stateful RNNs
to model long sequences efficiently.
'''
from __future__ import print_function
import numpy as np
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import Dense, LSTM
import matplotlib
# %matplotlib inline

# %%
# since we are using stateful rnn tsteps can be set to 1
tsteps = 1
batch_size = 25
epochs = 25
# number of elements ahead that are used to make the prediction
lahead = 1


def gen_cosine_amp(amp=100, period=1000, x0=0, xn=50000, step=1, k=0.0001):
    """Generates an absolute cosine time series with the amplitude
    exponentially decreasing
    Arguments:
        amp: amplitude of the cosine function
        period: period of the cosine function
        x0: initial x of the time series
        xn: final x of the time series
        step: step of the time series discretization
        k: exponential rate
    """
    cos = np.zeros(((xn - x0) * step, 1, 1))
    for i in range(len(cos)):
        idx = x0 + i * step
        cos[i, 0, 0] = amp * np.cos(2 * np.pi * idx / period)
        cos[i, 0, 0] = cos[i, 0, 0] * np.exp(-k * idx)
    return cos


print('Generating Data...')
cos = gen_cosine_amp()
print('Input shape:', cos.shape)

expected_output = np.zeros((len(cos), 1))
for i in range(len(cos) - lahead):
    expected_output[i, 0] = np.mean(cos[i + 1:i + lahead + 1])

print('Output shape:', expected_output.shape)

print('Creating Model...')
model = Sequential()
model.add(LSTM(50,
               input_shape=(tsteps, 1),
               batch_size=batch_size,
               return_sequences=True,
               stateful=True))
model.add(LSTM(50,
               return_sequences=False,
               stateful=True))
model.add(Dense(1))
model.compile(loss='mse', optimizer='rmsprop',validation_split=0.05)

print('Training')
loss = []
val_loss = []
for i in range(epochs):
    print('Epoch', i, '/', epochs)

    # Note that the last state for sample i in a batch will
    # be used as initial state for sample i in the next batch.
    # Thus we are simultaneously training on batch_size series with
    # lower resolution than the original series contained in cos.
    # Each of these series are offset by one step and can be
    # extracted with cos[i::batch_size].

    history = model.fit(cos, expected_output,
              batch_size=batch_size,
              epochs=1,
              verbose=1,
              shuffle=False,validation_split=0.05)
    loss.append(history.history['loss'])
    val_loss.append(history.history['val_loss'])
    model.reset_states()
    
# summarize history for loss
plt.figure(0)
plt.plot(loss,label='loss')
plt.plot(val_loss,label='val_loss')
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend()
plt.show()

print('Predicting')
predicted_output = model.predict(cos, batch_size=batch_size)

print('Plotting Results')
plt.figure(1)
plt.plot(expected_output,label='expected')
plt.plot(predicted_output,label='predicted')
plt.legend()
# plt.subplot(2, 1, 1)
# plt.plot(expected_output)
# plt.title('Expected')
# plt.subplot(2, 1, 2)
# plt.plot(predicted_output)
# plt.title('Predicted')
plt.show()
# Out:
# Generating Data...
# Input shape: (50000, 1, 1)
# Output shape: (50000, 1)
# Creating Model...
# Training
# Epoch 0 / 25
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-478e3547154e> in <module>()
#      66               epochs=1,
#      67               verbose=1,
# ---> 68               shuffle=False,validation_split=0.05)
#      69     loss.append(history.history['loss'])
#      70     val_loss.append(history.history['val_loss'])
#
# c:\users\cloud\anaconda2\envs\tensorflow\lib\site-packages\keras\models.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, **kwargs)
#     868                               class_weight=class_weight,
#     869                               sample_weight=sample_weight,
# --> 870                               initial_epoch=initial_epoch)
#     871
#     872     def evaluate(self, x, y, batch_size=32, verbose=1,
#
# c:\users\cloud\anaconda2\envs\tensorflow\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, **kwargs)
#    1472                 _slice_arrays(sample_weights, 0, split_at),
#    1473                 _slice_arrays(sample_weights, split_at))
# -> 1474             self._make_test_function()
#    1475             val_f = self.test_function
#    1476             if self.uses_learning_phase and not isinstance(K.learning_phase(), int):
#
# c:\users\cloud\anaconda2\envs\tensorflow\lib\site-packages\keras\engine\training.py in _make_test_function(self)
#    1034                                             updates=self.state_updates,
#    1035                                             name='test_function',
# -> 1036                                             **self._function_kwargs)
#    1037
#    1038     def _make_predict_function(self):
#
# c:\users\cloud\anaconda2\envs\tensorflow\lib\site-packages\keras\backend\tensorflow_backend.py in function(inputs, outputs, updates, **kwargs)
#    2291                     key not in inspect.getargspec(Function.__init__)[0]):
#    2292                 msg = 'Invalid argument "%s" passed to K.function with Tensorflow backend' % key
# -> 2293                 raise ValueError(msg)
#    2294     return Function(inputs, outputs, updates=updates, **kwargs)
#    2295
#
# ValueError: Invalid argument "validation_split" passed to K.function with Tensorflow backend
