# %%
'''Example script showing how to use stateful RNNs
to model long sequences efficiently.
'''
from __future__ import print_function
import numpy as np
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import Dense, LSTM
import matplotlib
# %matplotlib qt
# Out:
# Using TensorFlow backend.

# %%
# since we are using stateful rnn tsteps can be set to 1
tsteps = 1
batch_size = 25
epochs = 25
# number of elements ahead that are used to make the prediction
lahead = 1


def gen_cosine_amp(amp=100, period=1000, x0=0, xn=50000, step=1, k=0.0001):
    """Generates an absolute cosine time series with the amplitude
    exponentially decreasing
    Arguments:
        amp: amplitude of the cosine function
        period: period of the cosine function
        x0: initial x of the time series
        xn: final x of the time series
        step: step of the time series discretization
        k: exponential rate
    """
    cos = np.zeros(((xn - x0) * step, 1, 1))
    for i in range(len(cos)):
        idx = x0 + i * step
        cos[i, 0, 0] = amp * np.cos(2 * np.pi * idx / period)
        cos[i, 0, 0] = cos[i, 0, 0] * np.exp(-k * idx)
    return cos


print('Generating Data...')
cos = gen_cosine_amp()
print('Input shape:', cos.shape)

expected_output = np.zeros((len(cos), 1))
for i in range(len(cos) - lahead):
    expected_output[i, 0] = np.mean(cos[i + 1:i + lahead + 1])

print('Output shape:', expected_output.shape)

print('Creating Model...')
model = Sequential()
model.add(LSTM(50,
               input_shape=(tsteps, 1),
               batch_size=batch_size,
               return_sequences=True,
               stateful=True))
model.add(LSTM(50,
               return_sequences=False,
               stateful=True))
model.add(Dense(1))
model.compile(loss='mse', optimizer='rmsprop',validation_split=0.05)

print('Training')
loss = []
val_loss = []
for i in range(epochs):
    print('Epoch', i, '/', epochs)

    # Note that the last state for sample i in a batch will
    # be used as initial state for sample i in the next batch.
    # Thus we are simultaneously training on batch_size series with
    # lower resolution than the original series contained in cos.
    # Each of these series are offset by one step and can be
    # extracted with cos[i::batch_size].

    history = model.fit(cos, expected_output,
              batch_size=batch_size,
              epochs=1,
              verbose=1,
              shuffle=False,validation_split=0.05)
    loss.append(history.history['loss'])
    val_loss.append(history.history['val_loss'])
    model.reset_states()
    
# summarize history for loss
plt.figure(0)
plt.plot(loss,label='loss')
plt.plot(val_loss,label='val_loss')
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend()
plt.show()

print('Predicting')
predicted_output = model.predict(cos, batch_size=batch_size)

print('Plotting Results')
plt.figure(1)
plt.plot(expected_output,label='expected')
plt.plot(predicted_output,label='predicted')
plt.legend()
# plt.subplot(2, 1, 1)
# plt.plot(expected_output)
# plt.title('Expected')
# plt.subplot(2, 1, 2)
# plt.plot(predicted_output)
# plt.title('Predicted')
plt.show()
# Out:
# Generating Data...
# Input shape: (50000, 1, 1)
# Output shape: (50000, 1)
# Creating Model...
# Training
# Epoch 0 / 25
# Train on 47500 samples, validate on 2500 samples
# Epoch 1/1
# 47500/47500 [==============================] - 17s - loss: 371.3059 - val_loss: 0.0044
# Epoch 1 / 25
# Train on 47500 samples, validate on 2500 samples
# Epoch 1/1
# 47500/47500 [==============================] - 19s - loss: 166.5174 - val_loss: 0.0943
# Epoch 2 / 25
# Train on 47500 samples, validate on 2500 samples
# Epoch 1/1
# 47500/47500 [==============================] - 20s - loss: 126.2893 - val_loss: 0.8325
# Epoch 3 / 25
# Train on 47500 samples, validate on 2500 samples
# Epoch 1/1
# 47500/47500 [==============================] - 21s - loss: 74.8581 - val_loss: 0.2208
# Epoch 4 / 25
# Train on 47500 samples, validate on 2500 samples
# Epoch 1/1
# 47500/47500 [==============================] - 20s - loss: 49.1805 - val_loss: 0.2661
# Epoch 5 / 25
# Train on 47500 samples, validate on 2500 samples
# Epoch 1/1
# 47500/47500 [==============================] - 20s - loss: 37.5600 - val_loss: 0.0076
# Epoch 6 / 25
# Train on 47500 samples, validate on 2500 samples
# Epoch 1/1
# 47500/47500 [==============================] - 19s - loss: 40.9966 - val_loss: 0.0051
# Epoch 7 / 25
# Train on 47500 samples, validate on 2500 samples
# Epoch 1/1
# 47500/47500 [==============================] - 21s - loss: 37.9540 - val_loss: 0.2129
# Epoch 8 / 25
# Train on 47500 samples, validate on 2500 samples
# Epoch 1/1
# 47500/47500 [==============================] - 20s - loss: 19.7176 - val_loss: 0.0013
# Epoch 9 / 25
# Train on 47500 samples, validate on 2500 samples
# Epoch 1/1
# 47500/47500 [==============================] - 20s - loss: 14.3544 - val_loss: 0.0377
# Epoch 10 / 25
# Train on 47500 samples, validate on 2500 samples
# Epoch 1/1
# 47500/47500 [==============================] - 22s - loss: 10.4797 - val_loss: 0.0194
# Epoch 11 / 25
# Train on 47500 samples, validate on 2500 samples
# Epoch 1/1
# 47500/47500 [==============================] - 20s - loss: 8.6825 - val_loss: 0.0146
# Epoch 12 / 25
# Train on 47500 samples, validate on 2500 samples
# Epoch 1/1
# 47500/47500 [==============================] - 21s - loss: 7.3057 - val_loss: 0.0061
# Epoch 13 / 25
# Train on 47500 samples, validate on 2500 samples
# Epoch 1/1
# 47500/47500 [==============================] - 21s - loss: 6.3108 - val_loss: 0.0060
# Epoch 14 / 25
# Train on 47500 samples, validate on 2500 samples
# Epoch 1/1
# 47500/47500 [==============================] - 22s - loss: 5.6379 - val_loss: 0.0083
# Epoch 15 / 25
# Train on 47500 samples, validate on 2500 samples
# Epoch 1/1
# 47500/47500 [==============================] - 21s - loss: 5.0255 - val_loss: 0.0022
# Epoch 16 / 25
# Train on 47500 samples, validate on 2500 samples
# Epoch 1/1
# 47500/47500 [==============================] - 21s - loss: 4.7480 - val_loss: 0.0042
# Epoch 17 / 25
# Train on 47500 samples, validate on 2500 samples
# Epoch 1/1
# 47500/47500 [==============================] - 20s - loss: 4.5935 - val_loss: 0.0130
# Epoch 18 / 25
# Train on 47500 samples, validate on 2500 samples
# Epoch 1/1
# 47500/47500 [==============================] - 21s - loss: 3.9639 - val_loss: 0.0096
# Epoch 19 / 25
# Train on 47500 samples, validate on 2500 samples
# Epoch 1/1
# 47500/47500 [==============================] - 22s - loss: 3.4436 - val_loss: 0.0090
# Epoch 20 / 25
# Train on 47500 samples, validate on 2500 samples
# Epoch 1/1
# 47500/47500 [==============================] - 22s - loss: 3.1913 - val_loss: 0.0025
# Epoch 21 / 25
# Train on 47500 samples, validate on 2500 samples
# Epoch 1/1
# 47500/47500 [==============================] - 21s - loss: 3.0305 - val_loss: 0.0023
# Epoch 22 / 25
# Train on 47500 samples, validate on 2500 samples
# Epoch 1/1
# 47500/47500 [==============================] - 22s - loss: 3.0407 - val_loss: 0.0243
# Epoch 23 / 25
# Train on 47500 samples, validate on 2500 samples
# Epoch 1/1
# 47500/47500 [==============================] - 23s - loss: 2.8910 - val_loss: 0.0118
# Epoch 24 / 25
# Train on 47500 samples, validate on 2500 samples
# Epoch 1/1
# 47500/47500 [==============================] - 22s - loss: 2.6347 - val_loss: 0.0012
# Predicting
# Plotting Results
